# %%
# Lista de valores
valores = [12, 18, 25, 30, 10]

# Calcular promedio
promedio = sum(valores) / len(valores)

print("Lista de valores:", valores)
print("Promedio calculado:", promedio)
# Out:
# Lista de valores: [12, 18, 25, 30, 10]
# Promedio calculado: 19.0
